# %% [markdown]
# # **Name: Yamini Rajendra Chaudhari**
#
# # **GRIP:THE SPARKS FOUNDATION**
# ### Data Science & Business Analytics Tasks
# ## **TSF Task1 :Prediction using Supervised ML (Level - Beginner):**
# #### To Predict Percentage Score Of Students Given The Number Of Hours Of Study Using Simple Linear Regression.
#
# This is a simple linear regression task as it involves just 2 variables.

# %% [markdown]
# # **Importing Libraries**

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline # to enable the inline plotting

# %% [markdown]
# # **Importing dataset**

# %%
# Reading data from remote link
link = "http://bit.ly/w-data"
data = pd.read_csv(link)
data.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %% [markdown]
# # **Visualizing Dataset**

# %%
# Plotting the distribution of scores
Hours = data['Hours']
Scores = data['Scores']
plt.scatter(Hours, Scores)
plt.xlabel("Hours of Study",fontweight ='bold', fontsize = 10)
plt.ylabel("Percentage Scored",fontweight ='bold', fontsize = 10)
plt.title("Hours vs Scores",fontweight ='bold', fontsize = 15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
#  From the above graph , we can clearly see that there is a positive linear relation between the number of hours studied and percentage of score.

# %% [markdown]
# # Preparing the data
# The next step is to divide the data into "attributes" (inputs) and "labels" (outputs).

# %%
X=data.iloc[:, :-1].values     
Y=data.iloc[:, 1].values

# %% [markdown]
# * Now that we have our attributes and labels, the next step is to split this data into training and test sets.
# We'll do this by using Scikit-Learn's built-in train_test_split() method:

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.2, random_state=0)

# %% [markdown]
# # **Traing the model**
# Training the algorithm on the given data

# %%
from sklearn.linear_model import LinearRegression  
reg = LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Plotting the regression line
reg_line = reg.coef_*X+reg.intercept_
plt.scatter(X,Y)
plt.plot(X,reg_line)
plt.show()

# %% [markdown]
# # **Making predictions**

# %%
X_test
# Out:
# array([[1.5],
#        [3.2],
#        [7.4],
#        [2.5],
#        [5.9]])

# %%
Y_predicted = reg.predict(X_test)
Y_predicted
# Out:
# array([16.88414476, 33.73226078, 75.357018  , 26.79480124, 60.49103328])

# %%
d=[X_test, Y_test, Y_predicted]
d
# Out:
# [array([[1.5],
#         [3.2],
#         [7.4],
#         [2.5],
#         [5.9]]),
#  array([20, 27, 69, 30, 62]),
#  array([16.88414476, 33.73226078, 75.357018  , 26.79480124, 60.49103328])]

# %%
x = X_test.flatten()
x
# Out:
# array([1.5, 3.2, 7.4, 2.5, 5.9])

# %% [markdown]
# # **Comparing actual and predicted percentage scores for given hours of study.**
# Comparing the output obtained by testing our model with the given data.

# %%
d = pd.DataFrame({'Hours':x,'Actual Score': Y_test, 'Predicted Score': Y_predicted})  
d
# Out:
#    Hours  Actual Score  Predicted Score
# 0    1.5            20        16.884145
# 1    3.2            27        33.732261
# 2    7.4            69        75.357018
# 3    2.5            30        26.794801
# 4    5.9            62        60.491033

# %%
d.plot(kind='bar')

# %% [markdown]
# We can see the slight difference betweemn the actual and predicted values.

# %% [markdown]
# # **Predicting percentage for a student who studies for 9.25 hours**

# %%
hours = 9.25
pred = reg.predict([[hours]])
print("Number of Hours = {}".format(hours))
print("Predicted Score = {}".format(pred[0]))
# Out:
# Number of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# # **Evaluating the model**

# %%
from sklearn import metrics  
print('Mean Absolute Error Of The Model is:', 
      metrics.mean_absolute_error(Y_test, Y_predicted))
# Out:
# Mean Absolute Error Of The Model is: 4.183859899002982

# %% [markdown]
# #### Conclusion: Successfully completed the first task of data science &Business analytics internship program. Implemented Linear Regression model to predict percentage scored by students for the number of hours they study.
#
# # **THANK YOU**
